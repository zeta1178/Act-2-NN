# %% [markdown]
# <a href="https://colab.research.google.com/github/zeta1178/Act-2-NN/blob/main/Tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn
import tensorflow as tf
import matplotlib.pyplot as plt

# Check for TensorFlow GPU access
print(tf.config.list_physical_devices())

# See TensorFlow version
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# 2.8.2

# %%
# Imports
import pandas as pd
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
# Read the cc_default.csv file from the Resources folder into a Pandas DataFrame
cc_df = pd.read_csv(
    Path("cc_default.csv")
)

# Review the DataFrame
cc_df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -2  ...                     0          0          0         0       689
# 1      0  ...                  3272       3455       3261         0      1000
# 2      0  ...                 14331      14948      15549      1518      1500
# 3      0  ...                 28314      28959      29547      2000      2019
# 4      0  ...                 20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %%
# Define features set X by selecting all columns but DEFAULT
X = cc_df.drop(columns=["DEFAULT"]).copy()

# Display the features DataFrame
X.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT3           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  \
# 0     -2  ...        689                     0          0          0
# 1      0  ...       2682                  3272       3455       3261
# 2      0  ...      13559                 14331      14948      15549
# 3      0  ...      49291                 28314      28959      29547
# 4      0  ...      35835                 20940      19146      19131
#
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
# Define target set by selecting the DEFAULT column
y = cc_df["DEFAULT"]

# Display a sample of y
y[:5]
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: DEFAULT, dtype: int64
